# %%
import pandas as pd

# %%
df = pd.read_csv("/workspaces/agriculture-data-analysis/data/agriculture-value-added-per-worker-wdi.csv")
df1 = pd.read_csv("../data/API_AG.PRD.FOOD.XD_DS2_en_csv_v2_143662/API_AG.PRD.FOOD.XD_DS2_en_csv_v2_143662.csv")
df2 =pd.read_csv("../data/API_AG.CON.FERT.ZS_DS2_en_csv_v2_46344/API_AG.CON.FERT.ZS_DS2_en_csv_v2_46344.csv")

# %%
df
india_data = df[df['Entity'] == 'India']
india_data
# Out:
#      Entity Code  Year  \
# 1954  India  IND  1991
# 1955  India  IND  1992
# 1956  India  IND  1993
# 1957  India  IND  1994
# 1958  India  IND  1995
# 1959  India  IND  1996
# 1960  India  IND  1997
# 1961  India  IND  1998
# 1962  India  IND  1999
# 1963  India  IND  2000
# 1964  India  IND  2001
# 1965  India  IND  2002
# 1966  India  IND  2003
# 1967  India  IND  2004
# 1968  India  IND  2005
# 1969  India  IND  2006
# 1970  India  IND  2007
# 1971  India  IND  2008
# 1972  India  IND  2009
# 1973  India  IND  2010
# 1974  India  IND  2011
# 1975  India  IND  2012
# 1976  India  IND  2013
# 1977  India  IND  2014
# 1978  India  IND  2015
# 1979  India  IND  2016
# 1980  India  IND  2017
# 1981  India  IND  2018
# 1982  India  IND  2019
#
#       Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)
# 1954                                          864.69730
# 1955                                          906.39880
# ...

# %%
df1
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                               Indicator Name  Indicator Code   1961   1962  \
# 0    Food production index (2014-2016 = 100)  AG.PRD.FOOD.XD    NaN    NaN
# 1    Food production index (2014-2016 = 100)  AG.PRD.FOOD.XD    NaN    NaN
# 2    Food production index (2014-2016 = 100)  AG.PRD.FOOD.XD  41.00  41.34
# 3    Food production index (2014-2016 = 100)  AG.PRD.FOOD.XD    NaN    NaN
# ...

# %%
df1
india_data1 = df1[df1['Country Name'] == 'India']
india_data1
# Out:
#     Country Name Country Code                           Indicator Name  \
# 109        India          IND  Food production index (2014-2016 = 100)
#
#      Indicator Code   1961   1962   1963   1964   1965   1966  ...   2013  \
# 109  AG.PRD.FOOD.XD  22.43  22.13  22.62  23.16  22.11  21.99  ...  96.65
#
#       2014   2015    2016    2017   2018    2019    2020    2021    2022
# 109  99.24  98.45  102.31  108.94  114.2  116.26  120.12  126.11  127.82
#
# [1 rows x 66 columns]

# %%
df2
india_data2 = df2[df2["Country Name"] == "India"]
columns_to_drop = ['1960','2023','2022','Unnamed: 68'] 
india_data2.drop(columns= columns_to_drop, inplace =True)
india_data2
# Out:
# /tmp/ipykernel_7993/1737455823.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_data2.drop(columns= columns_to_drop, inplace =True)
#     Country Name Country Code  \
# 109        India          IND
#
#                                         Indicator Name  Indicator Code  \
# 109  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
#
#         1961      1962      1963      1964      1965      1966  ...  \
# 109  2.17129  2.885769  3.453991  4.901986  4.959043  6.939908  ...
#
#            2012        2013        2014        2015        2016        2017  \
# 109  163.122022  156.495698  163.498079  171.038213  166.003058  170.569145
#
#            2018        2019       2020        2021
# 109  176.071313  186.456666  210.65738  193.245041
#
# [1 rows x 65 columns]
