# %%
import pandas as pd

# %%
df = pd.read_csv("../data/agriculture-value-added-per-worker-wdi.csv")

# %%
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2002
# 1     Afghanistan  AFG  2003
# 2     Afghanistan  AFG  2004
# 3     Afghanistan  AFG  2005
# 4     Afghanistan  AFG  2006
# ...           ...  ...   ...
# 4868     Zimbabwe  ZWE  2014
# 4869     Zimbabwe  ZWE  2015
# 4870     Zimbabwe  ZWE  2016
# 4871     Zimbabwe  ZWE  2017
# 4872     Zimbabwe  ZWE  2018
#
#       Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)
# 0                                            1066.79460
# 1                                            1049.99480
# 2                                             780.23290
# 3                                             892.63430
# 4                                             836.60864
# ...                                                 ...
# 4868                                          422.50128
# 4869                                          395.20074
# 4870                                          375.09372
# ...
